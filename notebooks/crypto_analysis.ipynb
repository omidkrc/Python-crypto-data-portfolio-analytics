# %%
## installing packages

#pip install alphavantage
#pip install matplotlib.pyplot
#pip install pandas
#pip install numpy
#pip install datetime
#pip install requests
#pip install math
#pip install yahoo-finance
#pip install pandas_datareader
#pip install plotly
#pip install statsmodels
#pip install yfinance

# %%
## importing packages

import numpy as np
import pandas_datareader
from pandas_datareader import data as wb
from pandas_datareader import yahoo
import pandas as pd
import requests
from datetime import datetime
import math
import plotly
import plotly.graph_objects as go
import yfinance as yf
import matplotlib.pyplot as plt

# %%
## Question 1, part a

# %%
# Define tickers
tickers = ['BTC-USD', 'ETH-USD', 'BNB-USD', 'XRP-USD', 'ADA-USD']

# download data
data1 = pd.DataFrame()

for t in tickers:
    data1[t] = yf.download(t, start="2022-01-01", end="2022-12-31")['Close']

# renaming the data frame columns, showing the data frame
data1 = data1.rename(columns={ 'BTC-USD': 'Bitcoin', 'ETH-USD': 'Ethereum', 'BNB-USD': 'Binance coin', 'XRP-USD': 'Ripple', 'ADA-USD': 'Cardano'})
data1
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Bitcoin     Ethereum  Binance coin    Ripple   Cardano
# Date
# 2022-01-01  47686.812500  3769.697021    527.352722  0.849472  1.376975
# 2022-01-02  47345.218750  3829.564941    531.396667  0.859118  1.377584
# 2022-01-03  46458.117188  3761.380371    512.135986  0.832885  1.321637
# 2022-01-04  45897.574219  3794.056641    507.506104  0.824673  1.311658
# 2022-01-05  43569.003906  3550.386963    475.056946  0.774358  1.236002
# ...                  ...          ...           ...       ...       ...
# 2022-12-26  16919.804688  1226.974365    244.198288  0.365723  0.265297
# 2022-12-27  16717.173828  1212.791626    246.596680  0.368126  0.260370
# 2022-12-28  16552.572266  1189.986084    244.141922  0.356531  0.248378
# 2022-12-29  16642.341797  1201.595337    246.479721  0.342846  0.244140
# 2022-12-30  16602.585938  1199.232788    245.779221  0.345017  0.245557
#
# [364 rows x 5 columns]

# %%
# calculating mean and standard deviation of price data of cryptos

data1_mean = data1.mean()
data1_std = data1.std()

# %%
# scaling the price data of cryptos, showing the price trend for which based on a scaled diagram that each one starts form price=100

data1_scaled = (data1 - data1_mean) / data1_std
(data1_scaled / data1_scaled.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %%
# calculating the cumulative return for each crypto

data1_returns = (data1 / data1.shift(1)) - 1
cumulative_return = (1 + data1_returns).product() - 1
cumulative_return
# Out:
# Bitcoin        -0.651841
# Ethereum       -0.681876
# Binance coin   -0.533938
# Ripple         -0.593845
# Cardano        -0.821669
# dtype: float64

# %%
## Question 1, part b

# %%
# Define the tickers
tickers = ['BTC-USD', 'ETH-USD', 'BNB-USD', 'XRP-USD', 'ADA-USD', 'DOGE-USD', 'SOL-USD', 'MATIC-USD', 'TRX-USD', 'LTC-USD']

# download data for the last year
data2 = pd.DataFrame()

for t in tickers:
    data2[t] = yf.download(t, start="2022-12-26", end="2023-06-26")['Close']

# renaming the data frame columns, showing the data frame
data2 = data2.rename(columns={ 'BTC-USD': 'Bitcoin', 'ETH-USD': 'Ethereum', 'BNB-USD': 'Binance coin', 'XRP-USD': 'Ripple', 'ADA-USD': 'Cardano',
 'DOGE-USD': 'Dogecoin', 'SOL-USD': 'Solana', 'MATIC-USD': 'Polygon', 'TRX-USD': 'Tronix', 'LTC-USD': 'Litecoin'})

data2
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Bitcoin     Ethereum  Binance coin    Ripple   Cardano  \
# Date
# 2022-12-26  16919.804688  1226.974365    244.198288  0.365723  0.265297
# 2022-12-27  16717.173828  1212.791626    246.596680  0.368126  0.260370
# 2022-12-28  16552.572266  1189.986084    244.141922  0.356531  0.248378
# 2022-12-29  16642.341797  1201.595337    246.479721  0.342846  0.244140
# 2022-12-30  16602.585938  1199.232788    245.779221  0.345017  0.245557
# ...                  ...          ...           ...       ...       ...
# 2023-06-21  30027.296875  1891.007202    249.286346  0.500695  0.287000
# 2023-06-22  29912.281250  1872.942993    240.792435  0.494975  0.290313
# 2023-06-23  30695.468750  1892.862061    244.564941  0.496566  0.296482
# 2023-06-24  30548.695312  1876.059692    236.659653  0.487313  0.290012
# 2023-06-25  30480.261719  1900.506104    238.892990  0.490277  0.292325
#
#             Dogecoin     Solana   Polygon    Tronix   Litecoin
# Date
# 2022-12-26  0.075783  11.306611  0.813517  0.054552  70.684746
# 2022-12-27  0.073724  11.085430  0.806025  0.054106  68.747910
# 2022-12-28  0.070381   9.755906  0.782831  0.054145  66.339066
# 2022-12-29  0.071042   9.651783  0.777419  0.054014  66.751076
# 2022-12-30  0.068404   9.880177  0.760533  0.054374  67.994034
# ...              ...        ...       ...       ...        ...
# 2023-06-21  0.065704  17.257046  0.669695  0.072384  85.147743
# 2023-06-22  0.065643  16.642620  0.656791  0.071936  86.070221
# 2023-06-23  0.068174  17.149534  0.675090  0.073152  91.209457
# 2023-06-24  0.066742  16.652863  0.655299  0.072247  89.744026
# 2023-06-25  0.066764  16.971380  0.667584  0.073204  88.275169
#
# [182 rows x 10 columns]

# %%
# calculating the daily returns for cryptos
data2_returns = (data2 / data2.shift(1)) - 1
data2_returns

# define the tickers
tickers2 = ['Bitcoin', 'Ethereum', 'Binance coin', 'Ripple', 'Cardano', 'Dogecoin', 'Solana', 'Polygon', 'Tronix', 'Litecoin']

# calculating number of days with positive and negative returns for each cryptocurrency, printing the results
for crypto in tickers2:
    positive_days = (data2_returns[crypto] > 0).sum()
    negative_days = (data2_returns[crypto] < 0).sum()
    print(f'{crypto} has positive daily return for {positive_days} days and negative daily return for {negative_days} days')
# Out:
# Bitcoin has positive daily return for 89 days and negative daily return for 92 days
# Ethereum has positive daily return for 91 days and negative daily return for 90 days
# Binance coin has positive daily return for 95 days and negative daily return for 86 days
# Ripple has positive daily return for 97 days and negative daily return for 84 days
# Cardano has positive daily return for 91 days and negative daily return for 90 days
# Dogecoin has positive daily return for 93 days and negative daily return for 88 days
# Solana has positive daily return for 90 days and negative daily return for 91 days
# Polygon has positive daily return for 90 days and negative daily return for 91 days
# Tronix has positive daily return for 101 days and negative daily return for 80 days
# Litecoin has positive daily return for 99 days and negative daily return for 82 days

# %%
# calculating cumulative return for altcoins when bitcoin daily return is negative or positive using ∏(1 + returns𝑖) formula, printing the results
btc_returns = data2_returns['Bitcoin']
alt_returns_when_btc_positive = (1 + data2_returns[btc_returns > 0]).prod() - 1
alt_returns_when_btc_negative = (1 + data2_returns[btc_returns < 0]).prod() - 1

print('\nCumulative return for altcoins when bitcoin daily return is positive:')
print(alt_returns_when_btc_positive)
print('\nCumulative return for altcoins when bitcoin daily return is negative:')
print(alt_returns_when_btc_negative)
# Out:
# Cumulative return for altcoins when bitcoin daily return is positive:
# Bitcoin          5.606179
# Ethereum         5.017691
# Binance coin     2.218003
# Ripple           3.601532
# Cardano          5.935583
# Dogecoin         3.470710
# Solana          12.919585
# Polygon          5.185214
# Tronix           2.629412
# Litecoin         4.787951
# dtype: float64
#
# Cumulative return for altcoins when bitcoin daily return is negative:
# Bitcoin        -0.727308
# Ethereum       -0.742603
# Binance coin   -0.695999
# Ripple         -0.708669
# Cardano        -0.841127
# Dogecoin       -0.802942
# Solana         -0.892165
# Polygon        -0.867326
# Tronix         -0.630267
# Litecoin       -0.784232
# dtype: float64

# %%
## Question 2, part a

# %%
# Define the tickers
tickers = ['BTC-USD', 'ETH-USD', 'XRP-USD']

# download the data for the last year
data3 = pd.DataFrame()

for t in tickers:
    data3[t] = yf.download(t, start="2022-01-01", end="2022-12-31")['Close']

# renaming the data frame columns, showing the data frame
data3 = data3.rename(columns={ 'BTC-USD': 'Bitcoin', 'ETH-USD': 'Ethereum', 'XRP-USD': 'Ripple' })

data3
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Bitcoin     Ethereum    Ripple
# Date
# 2022-01-01  47686.812500  3769.697021  0.849472
# 2022-01-02  47345.218750  3829.564941  0.859118
# 2022-01-03  46458.117188  3761.380371  0.832885
# 2022-01-04  45897.574219  3794.056641  0.824673
# 2022-01-05  43569.003906  3550.386963  0.774358
# ...                  ...          ...       ...
# 2022-12-26  16919.804688  1226.974365  0.365723
# 2022-12-27  16717.173828  1212.791626  0.368126
# 2022-12-28  16552.572266  1189.986084  0.356531
# 2022-12-29  16642.341797  1201.595337  0.342846
# 2022-12-30  16602.585938  1199.232788  0.345017
#
# [364 rows x 3 columns]

# %%
# calculate daily returns
log_returns3 = np.log(data3 / data3.shift(1))
log_returns3

# calculate annual returns
annual_returns3 = log_returns3.mean() * 363
annual_returns3

# define the weights
weights = np.arange(0, 1.05, 0.05)

# calculate portfolio return and volatility for each possible composition
portfolio_returns = []
portfolio_volatilities = []
portfolio_weights = []

for i in range(len(weights)):
    for j in range(len(weights)):
        for k in range(len(weights)):
            if weights[i] + weights[j] + weights[k] == 1:
                new_weights = [weights[i], weights[j], weights[k]]
                portfolio_return = np.sum(annual_returns3* new_weights)
                portfolio_variance = np.dot(np.array(new_weights).T, np.dot(log_returns3.cov() * 363, new_weights))
                portfolio_volatility = np.sqrt(portfolio_variance)
                portfolio_weights.append(new_weights)
                portfolio_returns.append(portfolio_return)
                portfolio_volatilities.append(portfolio_volatility)

# Print the results
# Consider that first element in every matrix relates to Bitcoin, second relates to Ethereum and third one relates to Ripple
for i in range(len(portfolio_returns)):
    print('Weights:', np.round(portfolio_weights[i], 4))
    print('Portfolio Return:', round(portfolio_returns[i], 4))
    print('Portfolio Volatility:', round(portfolio_volatilities[i], 4))
    print()
# Out:
# Weights: [0. 0. 1.]
# Portfolio Return: -0.901
# Portfolio Volatility: 0.8502
#
# Weights: [0.   0.05 0.95]
# Portfolio Return: -0.9132
# Portfolio Volatility: 0.8414
#
# Weights: [0.  0.1 0.9]
# Portfolio Return: -0.9255
# Portfolio Volatility: 0.8335
#
# Weights: [0.   0.15 0.85]
# Portfolio Return: -0.9377
# Portfolio Volatility: 0.8266
#
# Weights: [0.  0.2 0.8]
# Portfolio Return: -0.9499
# Portfolio Volatility: 0.8207
#
# Weights: [0.   0.25 0.75]
# Portfolio Return: -0.9621
# Portfolio Volatility: 0.8158
#
# Weights: [0.  0.3 0.7]
# Portfolio Return: -0.9743
# Portfolio Volatility: 0.812
#
# Weights: [0.   0.35 0.65]
# Portfolio Return: -0.9865
# Portfolio Volatility: 0.8093
#
# Weights: [0.  0.4 0.6]
# Portfolio Return: -0.9987
# Portfolio Volatility: 0.8077
#
# Weights: [0.   0.45 0.55]
# Portfolio Return: -1.011
# Portfolio Volatility: 0.8072
#
# Weights: [0.  0.5 0.5]
# Portfolio Return: -1.0232
# Portfolio Volatility: 0.8077
#
# Weights: [0.   0.55 0.45]
# Portfolio Return: -1.0354
# Portfolio Volatility: 0.8094
#
# Weights: [0.  0.6 0.4]
# Portfolio Return: -1.0476
# Portfolio Volatility: 0.8121
#
# Weights: [0.   0.65 0.35]
# Portfolio Return: -1.0598
# Portfolio Volatility: 0.8159
#
# Weights: [0.  0.7 0.3]
# Portfolio Return: -1.072
# Portfolio Volatility: 0.8208
#
# Weights: [0.   0.75 0.25]
# Portfolio Return: -1.0842
# Portfolio Volatility: 0.8267
#
# Weights: [0.  0.8 0.2]
# Portfolio Return: -1.0965
# Portfolio Volatility: 0.8336
#
# Weights: [0.   0.85 0.15]
# Portfolio Return: -1.1087
# Portfolio Volatility: 0.8415
#
# Weights: [0.  0.9 0.1]
# Portfolio Return: -1.1209
# Portfolio Volatility: 0.8504
#
# Weights: [0.   0.95 0.05]
# Portfolio Return: -1.1331
# Portfolio Volatility: 0.8602
#
# Weights: [0. 1. 0.]
# Portfolio Return: -1.1453
# Portfolio Volatility: 0.871
#
# Weights: [0.05 0.   0.95]
# Portfolio Return: -0.9087
# Portfolio Volatility: 0.8322
#
# Weights: [0.05 0.05 0.9 ]
# Portfolio Return: -0.9209
# Portfolio Volatility: 0.8239
#
# Weights: [0.05 0.1  0.85]
# Portfolio Return: -0.9332
# Portfolio Volatility: 0.8166
#
# Weights: [0.05 0.15 0.8 ]
# Portfolio Return: -0.9454
# Portfolio Volatility: 0.8103
#
# Weights: [0.05 0.2  0.75]
# Portfolio Return: -0.9576
# Portfolio Volatility: 0.8051
#
# Weights: [0.05 0.25 0.7 ]
# Portfolio Return: -0.9698
# Portfolio Volatility: 0.8009
#
# Weights: [0.05 0.3  0.65]
# Portfolio Return: -0.982
# Portfolio Volatility: 0.7978
#
# Weights: [0.05 0.35 0.6 ]
# Portfolio Return: -0.9942
# Portfolio Volatility: 0.7959
#
# Weights: [0.05 0.4  0.55]
# Portfolio Return: -1.0064
# Portfolio Volatility: 0.795
#
# Weights: [0.05 0.45 0.5 ]
# Portfolio Return: -1.0187
# Portfolio Volatility: 0.7952
#
# Weights: [0.05 0.5  0.45]
# Portfolio Return: -1.0309
# Portfolio Volatility: 0.7966
#
# Weights: [0.05 0.55 0.4 ]
# Portfolio Return: -1.0431
# Portfolio Volatility: 0.799
#
# Weights: [0.05 0.65 0.3 ]
# Portfolio Return: -1.0675
# Portfolio Volatility: 0.8072
#
# Weights: [0.05 0.7  0.25]
# Portfolio Return: -1.0797
# Portfolio Volatility: 0.8129
#
# Weights: [0.05 0.75 0.2 ]
# Portfolio Return: -1.0919
# Portfolio Volatility: 0.8196
#
# Weights: [0.05 0.8  0.15]
# Portfolio Return: -1.1042
# Portfolio Volatility: 0.8274
#
# Weights: [0.05 0.9  0.05]
# Portfolio Return: -1.1286
# Portfolio Volatility: 0.8458
#
# Weights: [0.05 0.95 0.  ]
# Portfolio Return: -1.1408
# Portfolio Volatility: 0.8564
#
# Weights: [0.1 0.  0.9]
# Portfolio Return: -0.9164
# Portfolio Volatility: 0.8147
#
# Weights: [0.1  0.05 0.85]
# Portfolio Return: -0.9286
# Portfolio Volatility: 0.807
#
# Weights: [0.1 0.1 0.8]
# Portfolio Return: -0.9409
# Portfolio Volatility: 0.8003
#
# Weights: [0.1  0.15 0.75]
# Portfolio Return: -0.9531
# Portfolio Volatility: 0.7947
#
# Weights: [0.1 0.2 0.7]
# Portfolio Return: -0.9653
# Portfolio Volatility: 0.7901
#
# Weights: [0.1  0.25 0.65]
# Portfolio Return: -0.9775
# Portfolio Volatility: 0.7867
#
# Weights: [0.1 0.3 0.6]
# Portfolio Return: -0.9897
# Portfolio Volatility: 0.7843
#
# Weights: [0.1  0.35 0.55]
# Portfolio Return: -1.0019
# Portfolio Volatility: 0.7831
#
# Weights: [0.1 0.4 0.5]
# Portfolio Return: -1.0141
# Portfolio Volatility: 0.7831
#
# Weights: [0.1  0.45 0.45]
# Portfolio Return: -1.0264
# Portfolio Volatility: 0.7841
#
# Weights: [0.1 0.5 0.4]
# Portfolio Return: -1.0386
# Portfolio Volatility: 0.7863
#
# Weights: [0.1  0.55 0.35]
# Portfolio Return: -1.0508
# Portfolio Volatility: 0.7895
#
# Weights: [0.1 0.6 0.3]
# Portfolio Return: -1.063
# Portfolio Volatility: 0.7939
#
# Weights: [0.1  0.65 0.25]
# Portfolio Return: -1.0752
# Portfolio Volatility: 0.7994
#
# Weights: [0.1 0.7 0.2]
# Portfolio Return: -1.0874
# Portfolio Volatility: 0.8059
#
# Weights: [0.1  0.75 0.15]
# Portfolio Return: -1.0996
# Portfolio Volatility: 0.8135
#
# Weights: [0.1 0.8 0.1]
# Portfolio Return: -1.1119
# Portfolio Volatility: 0.822
#
# Weights: [0.1  0.85 0.05]
# Portfolio Return: -1.1241
# Portfolio Volatility: 0.8315
#
# Weights: [0.1 0.9 0. ]
# Portfolio Return: -1.1363
# Portfolio Volatility: 0.842
#
# Weights: [0.15 0.   0.85]
# Portfolio Return: -0.9241
# Portfolio Volatility: 0.7977
#
# Weights: [0.15 0.05 0.8 ]
# Portfolio Return: -0.9363
# Portfolio Volatility: 0.7907
#
# Weights: [0.15 0.1  0.75]
# Portfolio Return: -0.9486
# Portfolio Volatility: 0.7847
#
# Weights: [0.15 0.15 0.7 ]
# Portfolio Return: -0.9608
# Portfolio Volatility: 0.7797
#
# Weights: [0.15 0.2  0.65]
# Portfolio Return: -0.973
# Portfolio Volatility: 0.7759
#
# Weights: [0.15 0.25 0.6 ]
# Portfolio Return: -0.9852
# Portfolio Volatility: 0.7732
#
# Weights: [0.15 0.3  0.55]
# Portfolio Return: -0.9974
# Portfolio Volatility: 0.7716
#
# Weights: [0.15 0.35 0.5 ]
# Portfolio Return: -1.0096
# Portfolio Volatility: 0.7712
#
# Weights: [0.15 0.4  0.45]
# Portfolio Return: -1.0218
# Portfolio Volatility: 0.7719
#
# Weights: [0.15 0.45 0.4 ]
# Portfolio Return: -1.0341
# Portfolio Volatility: 0.7738
#
# Weights: [0.15 0.5  0.35]
# Portfolio Return: -1.0463
# Portfolio Volatility: 0.7768
#
# Weights: [0.15 0.55 0.3 ]
# Portfolio Return: -1.0585
# Portfolio Volatility: 0.7809
#
# Weights: [0.15 0.6  0.25]
# Portfolio Return: -1.0707
# Portfolio Volatility: 0.7862
#
# Weights: [0.15 0.65 0.2 ]
# Portfolio Return: -1.0829
# Portfolio Volatility: 0.7925
#
# Weights: [0.15 0.7  0.15]
# Portfolio Return: -1.0951
# Portfolio Volatility: 0.7998
#
# Weights: [0.15 0.75 0.1 ]
# Portfolio Return: -1.1074
# Portfolio Volatility: 0.8082
#
# Weights: [0.15 0.8  0.05]
# Portfolio Return: -1.1196
# Portfolio Volatility: 0.8176
#
# Weights: [0.15 0.85 0.  ]
# Portfolio Return: -1.1318
# Portfolio Volatility: 0.8279
#
# Weights: [0.2 0.  0.8]
# Portfolio Return: -0.9318
# Portfolio Volatility: 0.7815
#
# Weights: [0.2  0.05 0.75]
# Portfolio Return: -0.9441
# Portfolio Volatility: 0.775
#
# Weights: [0.2 0.1 0.7]
# Portfolio Return: -0.9563
# Portfolio Volatility: 0.7697
#
# Weights: [0.2  0.15 0.65]
# Portfolio Return: -0.9685
# Portfolio Volatility: 0.7655
#
# Weights: [0.2 0.2 0.6]
# Portfolio Return: -0.9807
# Portfolio Volatility: 0.7624
#
# Weights: [0.2  0.25 0.55]
# Portfolio Return: -0.9929
# Portfolio Volatility: 0.7605
#
# Weights: [0.2 0.3 0.5]
# Portfolio Return: -1.0051
# Portfolio Volatility: 0.7598
#
# Weights: [0.2  0.35 0.45]
# Portfolio Return: -1.0173
# Portfolio Volatility: 0.7601
#
# Weights: [0.2 0.4 0.4]
# Portfolio Return: -1.0296
# Portfolio Volatility: 0.7617
#
# Weights: [0.2  0.45 0.35]
# Portfolio Return: -1.0418
# Portfolio Volatility: 0.7644
#
# Weights: [0.2 0.5 0.3]
# Portfolio Return: -1.054
# Portfolio Volatility: 0.7683
#
# Weights: [0.2  0.55 0.25]
# Portfolio Return: -1.0662
# Portfolio Volatility: 0.7732
#
# Weights: [0.2 0.6 0.2]
# Portfolio Return: -1.0784
# Portfolio Volatility: 0.7793
#
# Weights: [0.2  0.65 0.15]
# Portfolio Return: -1.0906
# Portfolio Volatility: 0.7865
#
# Weights: [0.2  0.75 0.05]
# Portfolio Return: -1.1151
# Portfolio Volatility: 0.8039
#
# Weights: [0.2 0.8 0. ]
# Portfolio Return: -1.1273
# Portfolio Volatility: 0.8141
#
# Weights: [0.25 0.   0.75]
# Portfolio Return: -0.9395
# Portfolio Volatility: 0.7659
#
# Weights: [0.25 0.05 0.7 ]
# Portfolio Return: -0.9518
# Portfolio Volatility: 0.7601
#
# Weights: [0.25 0.1  0.65]
# Portfolio Return: -0.964
# Portfolio Volatility: 0.7555
#
# Weights: [0.25 0.15 0.6 ]
# Portfolio Return: -0.9762
# Portfolio Volatility: 0.7521
#
# Weights: [0.25 0.2  0.55]
# Portfolio Return: -0.9884
# Portfolio Volatility: 0.7498
#
# Weights: [0.25 0.25 0.5 ]
# Portfolio Return: -1.0006
# Portfolio Volatility: 0.7487
#
# Weights: [0.25 0.3  0.45]
# Portfolio Return: -1.0128
# Portfolio Volatility: 0.7487
#
# Weights: [0.25 0.35 0.4 ]
# Portfolio Return: -1.025
# Portfolio Volatility: 0.7499
#
# Weights: [0.25 0.4  0.35]
# Portfolio Return: -1.0373
# Portfolio Volatility: 0.7524
#
# Weights: [0.25 0.45 0.3 ]
# Portfolio Return: -1.0495
# Portfolio Volatility: 0.7559
#
# Weights: [0.25 0.5  0.25]
# Portfolio Return: -1.0617
# Portfolio Volatility: 0.7606
#
# Weights: [0.25 0.55 0.2 ]
# Portfolio Return: -1.0739
# Portfolio Volatility: 0.7665
#
# Weights: [0.25 0.6  0.15]
# Portfolio Return: -1.0861
# Portfolio Volatility: 0.7734
#
# Weights: [0.25 0.65 0.1 ]
# Portfolio Return: -1.0983
# Portfolio Volatility: 0.7814
#
# Weights: [0.25 0.7  0.05]
# Portfolio Return: -1.1105
# Portfolio Volatility: 0.7905
#
# Weights: [0.25 0.75 0.  ]
# Portfolio Return: -1.1228
# Portfolio Volatility: 0.8005
#
# Weights: [0.3 0.  0.7]
# Portfolio Return: -0.9472
# Portfolio Volatility: 0.751
#
# Weights: [0.3  0.05 0.65]
# Portfolio Return: -0.9595
# Portfolio Volatility: 0.746
#
# Weights: [0.3 0.1 0.6]
# Portfolio Return: -0.9717
# Portfolio Volatility: 0.7421
#
# Weights: [0.3  0.15 0.55]
# Portfolio Return: -0.9839
# Portfolio Volatility: 0.7394
#
# Weights: [0.3 0.2 0.5]
# Portfolio Return: -0.9961
# Portfolio Volatility: 0.7379
#
# Weights: [0.3  0.25 0.45]
# Portfolio Return: -1.0083
# Portfolio Volatility: 0.7377
#
# Weights: [0.3 0.3 0.4]
# Portfolio Return: -1.0205
# Portfolio Volatility: 0.7386
#
# Weights: [0.3 0.4 0.3]
# Portfolio Return: -1.045
# Portfolio Volatility: 0.7439
#
# Weights: [0.3  0.45 0.25]
# Portfolio Return: -1.0572
# Portfolio Volatility: 0.7484
#
# Weights: [0.3 0.5 0.2]
# Portfolio Return: -1.0694
# Portfolio Volatility: 0.754
#
# Weights: [0.3  0.55 0.15]
# Portfolio Return: -1.0816
# Portfolio Volatility: 0.7607
#
# Weights: [0.3  0.65 0.05]
# Portfolio Return: -1.106
# Portfolio Volatility: 0.7774
#
# Weights: [0.3 0.7 0. ]
# Portfolio Return: -1.1182
# Portfolio Volatility: 0.7872
#
# Weights: [0.35 0.   0.65]
# Portfolio Return: -0.9549
# Portfolio Volatility: 0.7368
#
# Weights: [0.35 0.05 0.6 ]
# Portfolio Return: -0.9672
# Portfolio Volatility: 0.7326
#
# Weights: [0.35 0.1  0.55]
# Portfolio Return: -0.9794
# Portfolio Volatility: 0.7295
#
# Weights: [0.35 0.15 0.5 ]
# Portfolio Return: -0.9916
# Portfolio Volatility: 0.7277
#
# Weights: [0.35 0.2  0.45]
# Portfolio Return: -1.0038
# Portfolio Volatility: 0.727
#
# Weights: [0.35 0.25 0.4 ]
# Portfolio Return: -1.016
# Portfolio Volatility: 0.7276
#
# Weights: [0.35 0.35 0.3 ]
# Portfolio Return: -1.0404
# Portfolio Volatility: 0.7323
#
# Weights: [0.35 0.4  0.25]
# Portfolio Return: -1.0527
# Portfolio Volatility: 0.7365
#
# Weights: [0.35 0.45 0.2 ]
# Portfolio Return: -1.0649
# Portfolio Volatility: 0.7418
#
# Weights: [0.35 0.5  0.15]
# Portfolio Return: -1.0771
# Portfolio Volatility: 0.7483
#
# Weights: [0.35 0.65 0.  ]
# Portfolio Return: -1.1137
# Portfolio Volatility: 0.7743
#
# Weights: [0.4 0.  0.6]
# Portfolio Return: -0.9627
# Portfolio Volatility: 0.7235
#
# Weights: [0.4  0.05 0.55]
# Portfolio Return: -0.9749
# Portfolio Volatility: 0.72
#
# Weights: [0.4 0.1 0.5]
# Portfolio Return: -0.9871
# Portfolio Volatility: 0.7178
#
# Weights: [0.4  0.15 0.45]
# Portfolio Return: -0.9993
# Portfolio Volatility: 0.7168
#
# Weights: [0.4 0.2 0.4]
# Portfolio Return: -1.0115
# Portfolio Volatility: 0.717
#
# Weights: [0.4  0.25 0.35]
# Portfolio Return: -1.0237
# Portfolio Volatility: 0.7184
#
# Weights: [0.4 0.3 0.3]
# Portfolio Return: -1.0359
# Portfolio Volatility: 0.7211
#
# Weights: [0.4  0.35 0.25]
# Portfolio Return: -1.0482
# Portfolio Volatility: 0.725
#
# Weights: [0.4 0.4 0.2]
# Portfolio Return: -1.0604
# Portfolio Volatility: 0.73
#
# Weights: [0.4  0.45 0.15]
# Portfolio Return: -1.0726
# Portfolio Volatility: 0.7363
#
# Weights: [0.4 0.5 0.1]
# Portfolio Return: -1.0848
# Portfolio Volatility: 0.7436
#
# Weights: [0.4  0.55 0.05]
# Portfolio Return: -1.097
# Portfolio Volatility: 0.7521
#
# Weights: [0.4 0.6 0. ]
# Portfolio Return: -1.1092
# Portfolio Volatility: 0.7616
#
# Weights: [0.45 0.   0.55]
# Portfolio Return: -0.9704
# Portfolio Volatility: 0.711
#
# Weights: [0.45 0.05 0.5 ]
# Portfolio Return: -0.9826
# Portfolio Volatility: 0.7084
#
# Weights: [0.45 0.1  0.45]
# Portfolio Return: -0.9948
# Portfolio Volatility: 0.707
#
# Weights: [0.45 0.15 0.4 ]
# Portfolio Return: -1.007
# Portfolio Volatility: 0.7068
#
# Weights: [0.45 0.2  0.35]
# Portfolio Return: -1.0192
# Portfolio Volatility: 0.7079
#
# Weights: [0.45 0.25 0.3 ]
# Portfolio Return: -1.0314
# Portfolio Volatility: 0.7103
#
# Weights: [0.45 0.3  0.25]
# Portfolio Return: -1.0436
# Portfolio Volatility: 0.7138
#
# Weights: [0.45 0.35 0.2 ]
# Portfolio Return: -1.0559
# Portfolio Volatility: 0.7186
#
# Weights: [0.45 0.4  0.15]
# Portfolio Return: -1.0681
# Portfolio Volatility: 0.7246
#
# Weights: [0.45 0.45 0.1 ]
# Portfolio Return: -1.0803
# Portfolio Volatility: 0.7317
#
# Weights: [0.45 0.5  0.05]
# Portfolio Return: -1.0925
# Portfolio Volatility: 0.74
#
# Weights: [0.45 0.55 0.  ]
# Portfolio Return: -1.1047
# Portfolio Volatility: 0.7493
#
# Weights: [0.5 0.  0.5]
# Portfolio Return: -0.9781
# Portfolio Volatility: 0.6994
#
# Weights: [0.5  0.05 0.45]
# Portfolio Return: -0.9903
# Portfolio Volatility: 0.6976
#
# Weights: [0.5 0.1 0.4]
# Portfolio Return: -1.0025
# Portfolio Volatility: 0.6971
#
# Weights: [0.5  0.15 0.35]
# Portfolio Return: -1.0147
# Portfolio Volatility: 0.6978
#
# Weights: [0.5 0.2 0.3]
# Portfolio Return: -1.0269
# Portfolio Volatility: 0.6999
#
# Weights: [0.5  0.25 0.25]
# Portfolio Return: -1.0391
# Portfolio Volatility: 0.7031
#
# Weights: [0.5 0.3 0.2]
# Portfolio Return: -1.0513
# Portfolio Volatility: 0.7076
#
# Weights: [0.5  0.35 0.15]
# Portfolio Return: -1.0636
# Portfolio Volatility: 0.7133
#
# Weights: [0.5 0.4 0.1]
# Portfolio Return: -1.0758
# Portfolio Volatility: 0.7202
#
# Weights: [0.5  0.45 0.05]
# Portfolio Return: -1.088
# Portfolio Volatility: 0.7282
#
# Weights: [0.5 0.5 0. ]
# Portfolio Return: -1.1002
# Portfolio Volatility: 0.7374
#
# Weights: [0.55 0.   0.45]
# Portfolio Return: -0.9858
# Portfolio Volatility: 0.6887
#
# Weights: [0.55 0.05 0.4 ]
# Portfolio Return: -0.998
# Portfolio Volatility: 0.6878
#
# Weights: [0.55 0.1  0.35]
# Portfolio Return: -1.0102
# Portfolio Volatility: 0.6882
#
# Weights: [0.55 0.15 0.3 ]
# Portfolio Return: -1.0224
# Portfolio Volatility: 0.6899
#
# Weights: [0.55 0.2  0.25]
# Portfolio Return: -1.0346
# Portfolio Volatility: 0.6928
#
# Weights: [0.55 0.25 0.2 ]
# Portfolio Return: -1.0468
# Portfolio Volatility: 0.697
#
# Weights: [0.55 0.3  0.15]
# Portfolio Return: -1.0591
# Portfolio Volatility: 0.7024
#
# Weights: [0.55 0.4  0.05]
# Portfolio Return: -1.0835
# Portfolio Volatility: 0.7168
#
# Weights: [0.55 0.45 0.  ]
# Portfolio Return: -1.0957
# Portfolio Volatility: 0.7258
#
# Weights: [0.6 0.  0.4]
# Portfolio Return: -0.9935
# Portfolio Volatility: 0.6791
#
# Weights: [0.6 0.1 0.3]
# Portfolio Return: -1.0179
# Portfolio Volatility: 0.6804
#
# Weights: [0.6  0.15 0.25]
# Portfolio Return: -1.0301
# Portfolio Volatility: 0.683
#
# Weights: [0.6 0.2 0.2]
# Portfolio Return: -1.0423
# Portfolio Volatility: 0.6868
#
# Weights: [0.6  0.25 0.15]
# Portfolio Return: -1.0545
# Portfolio Volatility: 0.692
#
# Weights: [0.6 0.4 0. ]
# Portfolio Return: -1.0912
# Portfolio Volatility: 0.7146
#
# Weights: [0.65 0.   0.35]
# Portfolio Return: -1.0012
# Portfolio Volatility: 0.6704
#
# Weights: [0.65 0.05 0.3 ]
# Portfolio Return: -1.0134
# Portfolio Volatility: 0.6714
#
# Weights: [0.65 0.1  0.25]
# Portfolio Return: -1.0256
# Portfolio Volatility: 0.6736
#
# Weights: [0.65 0.15 0.2 ]
# Portfolio Return: -1.0378
# Portfolio Volatility: 0.6771
#
# Weights: [0.65 0.2  0.15]
# Portfolio Return: -1.05
# Portfolio Volatility: 0.682
#
# Weights: [0.65 0.25 0.1 ]
# Portfolio Return: -1.0622
# Portfolio Volatility: 0.688
#
# Weights: [0.65 0.3  0.05]
# Portfolio Return: -1.0745
# Portfolio Volatility: 0.6953
#
# Weights: [0.65 0.35 0.  ]
# Portfolio Return: -1.0867
# Portfolio Volatility: 0.7038
#
# Weights: [0.7 0.  0.3]
# Portfolio Return: -1.0089
# Portfolio Volatility: 0.6628
#
# Weights: [0.7  0.05 0.25]
# Portfolio Return: -1.0211
# Portfolio Volatility: 0.6647
#
# Weights: [0.7 0.1 0.2]
# Portfolio Return: -1.0333
# Portfolio Volatility: 0.6679
#
# Weights: [0.7  0.15 0.15]
# Portfolio Return: -1.0455
# Portfolio Volatility: 0.6724
#
# Weights: [0.7  0.25 0.05]
# Portfolio Return: -1.0699
# Portfolio Volatility: 0.6852
#
# Weights: [0.7 0.3 0. ]
# Portfolio Return: -1.0822
# Portfolio Volatility: 0.6934
#
# Weights: [0.75 0.   0.25]
# Portfolio Return: -1.0166
# Portfolio Volatility: 0.6563
#
# Weights: [0.75 0.05 0.2 ]
# Portfolio Return: -1.0288
# Portfolio Volatility: 0.6592
#
# Weights: [0.75 0.1  0.15]
# Portfolio Return: -1.041
# Portfolio Volatility: 0.6634
#
# Weights: [0.75 0.15 0.1 ]
# Portfolio Return: -1.0532
# Portfolio Volatility: 0.6688
#
# Weights: [0.75 0.2  0.05]
# Portfolio Return: -1.0654
# Portfolio Volatility: 0.6756
#
# Weights: [0.75 0.25 0.  ]
# Portfolio Return: -1.0777
# Portfolio Volatility: 0.6835
#
# Weights: [0.8 0.  0.2]
# Portfolio Return: -1.0243
# Portfolio Volatility: 0.651
#
# Weights: [0.8  0.05 0.15]
# Portfolio Return: -1.0365
# Portfolio Volatility: 0.6548
#
# Weights: [0.8 0.1 0.1]
# Portfolio Return: -1.0487
# Portfolio Volatility: 0.66
#
# Weights: [0.8  0.15 0.05]
# Portfolio Return: -1.0609
# Portfolio Volatility: 0.6664
#
# Weights: [0.8 0.2 0. ]
# Portfolio Return: -1.0731
# Portfolio Volatility: 0.6741
#
# Weights: [0.85 0.   0.15]
# Portfolio Return: -1.032
# Portfolio Volatility: 0.6468
#
# Weights: [0.85 0.1  0.05]
# Portfolio Return: -1.0564
# Portfolio Volatility: 0.6577
#
# Weights: [0.85 0.15 0.  ]
# Portfolio Return: -1.0686
# Portfolio Volatility: 0.6651
#
# Weights: [0.9 0.  0.1]
# Portfolio Return: -1.0397
# Portfolio Volatility: 0.6438
#
# Weights: [0.9  0.05 0.05]
# Portfolio Return: -1.0519
# Portfolio Volatility: 0.6496
#
# Weights: [0.9 0.1 0. ]
# Portfolio Return: -1.0641
# Portfolio Volatility: 0.6567
#
# Weights: [0.95 0.   0.05]
# Portfolio Return: -1.0474
# Portfolio Volatility: 0.642
#
# Weights: [0.95 0.05 0.  ]
# Portfolio Return: -1.0596
# Portfolio Volatility: 0.6487
#
# Weights: [1. 0. 0.]
# Portfolio Return: -1.0551
# Portfolio Volatility: 0.6414

# %%
## Question 2, part b

# %%
# plot all possible sharpe ratios that could be obtained by chosen portfolios
risk_free_rate = 0

# method 1 for ploting
fig = go.Figure()
fig.add_trace(go.Scatter(x=list(portfolio_volatilities), 
                         y=list(portfolio_returns), 
                      #- Add color scale for sharpe ratio   
                      marker=dict(color=(np.array(portfolio_returns)-risk_free_rate)/(np.array(portfolio_volatilities)), 
                                  showscale=True, 
                                  size=7,
                                  line=dict(width=1),
                                  colorscale="RdBu",
                                  colorbar=dict(title="Sharpe<br>Ratio")
                                 ), 
                      mode='markers'))
# Add title/labels
fig.update_layout(template='plotly_white',
                  xaxis=dict(title='Annualised Risk (Volatility)'),
                  yaxis=dict(title='Annualised Return'),
                  title='Sample of chosen Portfolios',
                  coloraxis_colorbar=dict(title="Sharpe Ratio"))

# %%
# method 2 for ploting
x2 = portfolio_volatilities
y2 = portfolio_returns

plt.scatter(x2, y2)
plt.show()

# %%
# creating csv file containing portfolios of three cryptos, returns and variances for each combination of weights
portfolios_data_frame = pd.DataFrame(0,index=range(len(portfolio_weights)), columns=['Bitcoin-weight','Ethereum-weight','Ripple-weight','return','volatility','sharpe ratio' ])

for i in range(len(portfolio_weights)):
    portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
    portfolios_data_frame['Ethereum-weight'].loc[i]=portfolio_weights[i][1]
    portfolios_data_frame['Ripple-weight'].loc[i]=portfolio_weights[i][2]
    portfolios_data_frame['return'].loc[i]=portfolio_returns[i]
    portfolios_data_frame['volatility'].loc[i]=portfolio_volatilities[i]
    portfolios_data_frame['sharpe ratio'].loc[i]=portfolio_returns[i]/portfolio_volatilities[i]

portfolios_data_frame.to_csv('portfolios.csv')
# Out:
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['volatility'].loc[i]=portfolio_volatilities[i]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['sharpe ratio'].loc[i]=portfolio_returns[i]/portfolio_volatilities[i]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Ethereum-weight'].loc[i]=portfolio_weights[i][1]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Ripple-weight'].loc[i]=portfolio_weights[i][2]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]
# C:\Users\Naslejavan\AppData\Local\Temp\ipykernel_14436\3002456252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolios_data_frame['Bitcoin-weight'].loc[i]=portfolio_weights[i][0]

# %%
# calculating the best weights which give us the highest possible sharpe ratio, printing the results

sharpe_ratio = (np.array(portfolio_returns) - risk_free_rate)/(np.array(portfolio_volatilities))
sharpe_ratio

M = max(sharpe_ratio)
for i in range(0, np.array(sharpe_ratio.shape)[0]) :
     if sharpe_ratio[i] == M :
          print('Optimal weights to gain highest sharpe ratio are:', np.round(portfolio_weights[i], 4))
# Out:
# Optimal weights to gain highest sharpe ratio are: [0. 0. 1.]

# %%
# Question 3

# %%
# download the data for the last year
data4= pd.DataFrame()
data4= yf.download('BTC-USD', start="2021-09-01", end="2023-01-01")['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data=[]
for i in range(10,101,5):
    for j in range(5,i,5):

        #i is number of days of long moving average and j is number of days of short moving average
        sell= 0
        buy= 0
        wealth= 1
        wealth_transactioned= 1
        first_day= np.where(data4==data4.loc['2022-01-01'])[0][0]
        last_day= np.where(data4==data4.loc['2022-12-31'])[0][0]
        for t in range(first_day , last_day):

            #if short moving average is bigger than long moving average we have buy signal
            if sum(data4[t-j:t])/j > sum(data4[t-i:t])/i:
                buy+= 1
                wealth*= data4[t] / data4[t-1]
                wealth_transactioned*= 1 + 0.95*(data4[t] / data4[t-1] -1)
            
            #if long moving average is bigger than short moving average we have sell signal
            elif sum(data4[t-i:t])/i > sum(data4[t-j:t])/j:
                sell+= 1
        data.append([i,j,buy,sell,wealth,wealth_transactioned])

# %%
#finding maximum possible wealth
max_wealth=0
for i in range(np.shape(data)[0]):
    if data[i][4] > max_wealth:
        max_wealth= data[i][4]

#finding index of trading strategy which makes maximum possible wealth
for i in range(np.shape(data)[0]):
    if data[i][4] == max_wealth:
        max_index=i

# %%
#finding maximum possible transactioned wealth
max_transactioned_wealth=0
for i in range(np.shape(data)[0]):
    if data[i][5] > max_transactioned_wealth:
        max_transactioned_wealth= data[i][5]

#finding index of trading strategy which makes maximum possible transactioned wealth
for i in range(np.shape(data)[0]):
    if data[i][5] == max_transactioned_wealth:
        max_transactioned_index=i

# %%
# printing the results for part a
print("best trading strategy without transaction:")
print("long moving average days:  ",data[max_index][0])
print("short moving average days:  ",data[max_index][1])
print("buy signals:  ",data[max_index][2])
print("sell signals:  ",data[max_index][3])
print("ratio of wealth change:  ",data[max_index][4])
# Out:
# best trading strategy without transaction:
# long moving average days:   85
# short moving average days:   80
# buy signals:   59
# sell signals:   305
# ratio of wealth change:   1.0418990320503314

# %%
# printing the results for part b
print("best trading strategy with transaction:")
print("long moving average days:  ",data[max_transactioned_index][0])
print("short moving average days:  ",data[max_transactioned_index][1])
print("buy signals:  ",data[max_transactioned_index][2])
print("sell signals:  ",data[max_transactioned_index][3])
print("ratio of wealth change:  ",data[max_transactioned_index][5])
# Out:
# best trading strategy with transaction:
# long moving average days:   85
# short moving average days:   80
# buy signals:   59
# sell signals:   305
# ratio of wealth change:   1.041130669650329
